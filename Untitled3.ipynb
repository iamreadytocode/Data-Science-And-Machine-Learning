# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("/data_lec12.csv",index_col="Name")

# %%
df.head(10)
# Out:
#                            Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                    1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.             2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii                3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort             4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue      5       GB  1996.0  Role-Playing  Nintendo
# Tetris                        6       GB  1989.0        Puzzle  Nintendo
# New Super Mario Bros.         7       DS  2006.0      Platform  Nintendo
# Wii Play                      8      Wii  2006.0          Misc  Nintendo
# New Super Mario Bros. Wii     9      Wii  2009.0      Platform  Nintendo
# Duck Hunt                    10      NES  1984.0       Shooter  Nintendo
#
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.49     29.02      3.77         8.46
# ...

# %%
df.tail(12)
# Out:
#                                                      Rank Platform    Year  \
# Name
# Secret Files 2: Puritas Cordis                      16589       DS  2009.0
# Mezase!! Tsuri Master DS                            16590       DS  2009.0
# Mega Brain Boost                                    16591       DS  2008.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
# Eiyuu Densetsu: Sora no Kiseki Material Collect...  16593      PSP  2007.0
# Myst IV: Revelation                                 16594       PC  2004.0
# Plushees                                            16595       DS  2008.0
# Woody Woodpecker in Crazy Castle 5                  16596      GBA  2002.0
# Men in Black II: Alien Escape                       16597       GC  2003.0
# SCORE International Baja 1000: The Official Game    16598      PS2  2008.0
# Know How 2                                          16599       DS  2010.0
# ...

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.dtypes
# Out:
# Rank              int64
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df['Year'].describe()
# Out:
# count    16327.000000
# mean      2006.406443
# std          5.828981
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
df['Global_Sales'].describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.iloc[567]
# Out:
# Rank                        568
# Platform                     PS
# Year                     1998.0
# Genre                   Shooter
# Publisher       Electronic Arts
# NA_Sales                   1.44
# EU_Sales                   1.09
# JP_Sales                    0.0
# Other_Sales                0.14
# Global_Sales               2.67
# Name: Medal of Honor, dtype: object

# %%
df.loc["Tetris"]
# Out:
#         Rank Platform    Year   Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Tetris     6       GB  1989.0  Puzzle  Nintendo     23.20      2.26      4.22
# Tetris   156      NES  1988.0  Puzzle  Nintendo      2.97      0.69      1.81
#
#         Other_Sales  Global_Sales
# Name
# Tetris         0.58         30.26
# Tetris         0.11          5.58

# %%
df.loc["Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru"]
# Out:
# Rank                      16592
# Platform                    PSV
# Year                     2016.0
# Genre                    Action
# Publisher       dramatic create
# NA_Sales                    0.0
# EU_Sales                    0.0
# JP_Sales                   0.01
# Other_Sales                 0.0
# Global_Sales               0.01
# Name: Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru, dtype: object

# %%
df.sort_values(by="JP_Sales").tail(20)
# Out:
#                                                 Rank Platform    Year  \
# Name
# Dragon Quest VII: Warriors of Eden               243       PS  2000.0
# Monster Hunter Freedom Unite                     162      PSP  2008.0
# Mario Kart DS                                     12       DS  2005.0
# Brain Age: Train Your Brain in Minutes a Day      20       DS  2005.0
# Super Mario Land                                  22       GB  1989.0
# Tetris                                             6       GB  1989.0
# Pokemon X/Pokemon Y                               33      3DS  2013.0
# Dragon Quest IX: Sentinels of the Starry Skies   150       DS  2009.0
# Animal Crossing: New Leaf                         74      3DS  2012.0
# New Super Mario Bros. Wii                          9      Wii  2009.0
# Monster Hunter Freedom 3                         215      PSP  2010.0
# Brain Age 2: More Training in Minutes a Day       28       DS  2005.0
# ...

# %%
df.sort_values("Genre",ascending=False).tail(9)
# Out:
#                                             Rank Platform    Year   Genre  \
# Name
# The Getaway                                  362      PS2  2002.0  Action
# Naruto Shippuden: Dragon Blade Chronicles   8026      Wii  2009.0  Action
# Tornado                                    11940       DS     NaN  Action
# Grand Theft Auto: Liberty City Stories       361      PS2  2006.0  Action
# Chicken Riot                                5372      Wii  2010.0  Action
# Iron Man 2                                  5371       DS  2010.0  Action
# Driver 2 Advance                            5369      GBA  2002.0  Action
# Freeway                                     5368     2600  1980.0  Action
# Dead Island: Riptide                        2618     X360  2013.0  Action
#
#                                                              Publisher  \
# Name
# The Getaway                                Sony Computer Entertainment
# ...

# %%
df["Genre"].tail(15)
# Out:
# Name
# Carmageddon 64                                                       Action
# Bust-A-Move 3000                                                     Puzzle
# Breach                                                              Shooter
# Secret Files 2: Puritas Cordis                                    Adventure
# Mezase!! Tsuri Master DS                                             Sports
# Mega Brain Boost                                                     Puzzle
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru              Action
# Eiyuu Densetsu: Sora no Kiseki Material Collection Portable    Role-Playing
# Myst IV: Revelation                                               Adventure
# Plushees                                                         Simulation
# Woody Woodpecker in Crazy Castle 5                                 Platform
# Men in Black II: Alien Escape                                       Shooter
# ...

# %%
df[df["Genre"]=="Action"]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto: San Andreas                          18      PS2  2004.0
# Grand Theft Auto V                                     24     X360  2013.0
# Grand Theft Auto: Vice City                            25      PS2  2002.0
# Grand Theft Auto III                                   39      PS2  2001.0
# ...                                                   ...      ...     ...
# Original Frisbee Disc Sports: Ultimate & Golf       16567       DS  2007.0
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Planet Monsters                                     16585      GBA  2001.0
# Carmageddon 64                                      16586      N64  1999.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
#                                                      Genre  \
# ...

# %%
df[df["Year"]>2015]
# Out:
#                                                      Rank Platform    Year  \
# Name
# FIFA 17                                               222      PS4  2016.0
# Uncharted 4: A Thief's End                            272      PS4  2016.0
# Tom Clancy's The Division                             352      PS4  2016.0
# Far Cry: Primal                                       772      PS4  2016.0
# Tom Clancy's The Division                             847     XOne  2016.0
# ...                                                   ...      ...     ...
# Mighty No. 9                                        16565     XOne  2016.0
# Resident Evil 4 HD                                  16572     XOne  2016.0
# Farming 2017 - The Simulation                       16573      PS4  2016.0
# Rugby Challenge 3                                   16579     XOne  2016.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
# ...

# %%
df[df["Genre"].between("Action","Sports")]
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...
