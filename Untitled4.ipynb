# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
df=pd.read_csv("/content/data_Lec13.csv")

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df=df.drop(["Vehicle Size"], axis=1)
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df=df.rename(columns={"Engine Fuel Type":"FUel","Engine HP":"HP"})
df.head()
# Out:
#   Make       Model  Year                         FUel     HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df.shape
# Out:
# (11914, 15)

# %%
dupli=df[df.duplicated()]
print("The duplicated rows are ",dupli.shape)
dupli=dupli
# Out:
# The duplicated rows are  (0, 15)

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# FUel                 11911
# HP                   11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df=df.drop_duplicates()
df.head()
# Out:
#   Make       Model  Year                         FUel     HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df.shape
# Out:
# (11188, 15)

# %%
df.count()
# Out:
# Make                 11188
# Model                11188
# Year                 11188
# FUel                 11185
# HP                   11119
# Engine Cylinders     11158
# Transmission Type    11188
# Driven_Wheels        11188
# Number of Doors      11182
# Market Category       7823
# Vehicle Style        11188
# highway MPG          11188
# city mpg             11188
# Popularity           11188
# MSRP                 11188
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Year                    0
# FUel                    3
# HP                     69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3365
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# Make                 7735
# Model                7735
# Year                 7735
# FUel                 7735
# HP                   7735
# Engine Cylinders     7735
# Transmission Type    7735
# Driven_Wheels        7735
# Number of Doors      7735
# Market Category      7735
# Vehicle Style        7735
# highway MPG          7735
# city mpg             7735
# Popularity           7735
# MSRP                 7735
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# FUel                 0
# HP                   0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
sns.boxplot(x=df['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df['Engine Cylinders'])
# Out:
# <Axes: xlabel='Engine Cylinders'>

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Year                    6.0
# HP                    131.0
# Engine Cylinders        2.0
# Number of Doors         2.0
# highway MPG             8.0
# city mpg                6.0
# Popularity           1489.0
# MSRP                23252.5
# dtype: float64
# <ipython-input-28-88eb348100d4>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1=df.quantile(0.25)
# <ipython-input-28-88eb348100d4>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3=df.quantile(0.75)

# %%
df.corr()
# Out:
# <ipython-input-29-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       Year        HP  Engine Cylinders  Number of Doors  \
# Year              1.000000  0.234461         -0.051369         0.189846
# HP                0.234461  1.000000          0.811138        -0.212644
# Engine Cylinders -0.051369  0.811138          1.000000        -0.192441
# Number of Doors   0.189846 -0.212644         -0.192441         1.000000
# highway MPG       0.219893 -0.468328         -0.597864         0.114555
# city mpg          0.183083 -0.510151         -0.613399         0.150835
# Popularity        0.126803  0.036553          0.010051        -0.042345
# MSRP              0.125162  0.655522          0.589557        -0.193079
#
# ...

# %%
plt.figure(figsize(10,5))
correlation=df.corr()
sns.heatmap(correlation,cmap="BrBG",annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0f1fda110011> in <cell line: 1>()
# ----> 1 plt.figure(figsize(10,5))
#       2 correlation=df.corr()
#       3 sns.heatmap(correlation,cmap="BrBG",annot=True)
#
# NameError: name 'figsize' is not defined
